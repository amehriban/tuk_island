# %%
import xarray as xr
import geopandas as gpd
from shapely.geometry import box
from geocube.api.core import make_geocube

work_dir = "N:/permarisk/staff/mehribanaliyeva/lakestats/"
save_dir = "N:/permarisk/staff/mehribanaliyeva/lakestats/data/gridcells/"

# %%
work_dir + "hydrorivers/HydroRIVERS_v10.shp"
# Out:
# 'N:/permarisk/staff/mehribanaliyeva/lakestats/hydrorivers/HydroRIVERS_v10.shp'

# %%
gdf = gpd.read_file(work_dir+"hydrorivers/HydroRIVERS_v10.shp")

# %%
xminp, ymaxp = 60, 66.5625
xmaxp, yminp = xminp+2.5, ymaxp-1.875

# Create a bounding box geometry
bbox = box(xminp, yminp, xmaxp, ymaxp)

# Create a GeoDataFrame from the bounding box
bounding_box_gdf = gpd.GeoDataFrame(geometry=[bbox], crs=gdf.crs)

# Clip the shapefile to the bounding box
gdf_clipped = gpd.clip(gdf, bounding_box_gdf)

gdf_clipped = gdf_clipped.to_crs({'init': 'epsg:3995'})

# Define the output raster properties
# Change output path depending on lake or river grid
#gdf_geo_clipped_raster = save_dir+f'gridcell_rivers_{xminp}w{ymaxp}n.tif'
gdf_geo_clipped_raster = save_dir+f'gridcell_rivers_{xminp}w{ymaxp}n.tif'
pixel_size = 100  # Size of each pixel in the output raster
xmin, ymin, xmax, ymax = gdf_clipped.total_bounds
width = int((xmax - xmin) / pixel_size)
height = int((ymax - ymin) / pixel_size)


# Create a GeoCube object from the GeoDataFrame
cube = make_geocube(
    gdf_clipped,
    resolution=(pixel_size, pixel_size),
    fill=0
)

# Write the raster to a file
# ID_merged for lake grid and HYRIV_ID for river grid
cube['HYRIV_ID'].rio.to_raster(gdf_geo_clipped_raster)
# Out:
# c:\Users\mealiy001\AppData\Local\anaconda3\envs\geocube_env\Lib\site-packages\pyproj\crs\crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
import xarray as xr
import geopandas as gpd
from shapely.geometry import box
from geocube.api.core import make_geocube

work_dir = "//smb.isipd.dmawi.de/projects/permarisk/staff/mehribanaliyeva/lakestats/"
save_dir = "//smb.isipd.dmawi.de/projects/permarisk/staff/mehribanaliyeva/lakestats/data/gridcells/"

#change gdf path depending on if you want to update the lake grid or river grid
#ds = xr.open_dataset(work_dir+"ingmar/Lakes_Pekel_merged.nc")
gdf = gpd.read_file(work_dir+"hydrorivers/HydroRIVERS_v10.shp")

# Get the bounding box coordinates of the extent shapefile
#xminp, ymaxp = -157, 71
#xminp, ymaxp = -155, 70
#xminp, ymaxp = -76, 60
#xminp, ymaxp = 70, 72
#xminp, ymaxp = -78, 62
xminp, ymaxp = 60, 70
xmaxp, yminp = xminp+1, ymaxp-1

# Create a bounding box geometry
bbox = box(xminp, yminp, xmaxp, ymaxp)

# Create a GeoDataFrame from the bounding box
bounding_box_gdf = gpd.GeoDataFrame(geometry=[bbox], crs=gdf.crs)

# Clip the shapefile to the bounding box
gdf_clipped = gpd.clip(gdf, bounding_box_gdf)

gdf_clipped = gdf_clipped.to_crs({'init': 'epsg:3995'})

# Define the output raster properties
# Change output path depending on lake or river grid
#gdf_geo_clipped_raster = save_dir+f'gridcell_rivers_{xminp}w{ymaxp}n.tif'
gdf_geo_clipped_raster = save_dir+f'gridcell_rivers_{xminp}w{ymaxp}n.tif'
pixel_size = 100  # Size of each pixel in the output raster
xmin, ymin, xmax, ymax = gdf_clipped.total_bounds
width = int((xmax - xmin) / pixel_size)
height = int((ymax - ymin) / pixel_size)


# Create a GeoCube object from the GeoDataFrame
cube = make_geocube(
    gdf_clipped,
    resolution=(pixel_size, pixel_size),
    fill=0
)

# Write the raster to a file
# ID_merged for lake grid and HYRIV_ID for river grid
cube['HYRIV_ID'].rio.to_raster(gdf_geo_clipped_raster)
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[1], line 11
#       7 save_dir = "//smb.isipd.dmawi.de/projects/permarisk/staff/mehribanaliyeva/lakestats/data/gridcells/"
#       9 #change gdf path depending on if you want to update the lake grid or river grid
#      10 #ds = xr.open_dataset(work_dir+"ingmar/Lakes_Pekel_merged.nc")
# ---> 11 gdf = gpd.read_file(work_dir+"hydrorivers/HydroRIVERS_v10.shp")
#      13 # Get the bounding box coordinates of the extent shapefile
#      14 #xminp, ymaxp = -157, 71
#      15 #xminp, ymaxp = -155, 70
#      16 #xminp, ymaxp = -76, 60
#      17 #xminp, ymaxp = 70, 72
#      18 #xminp, ymaxp = -78, 62
#      19 xminp, ymaxp = 60, 70
#
# File c:\Users\mealiy001\AppData\Local\anaconda3\envs\geocube_env\Lib\site-packages\geopandas\io\file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
# ...
